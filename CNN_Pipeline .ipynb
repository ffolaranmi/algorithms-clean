# %%
import os
import sklearn
import numpy as np
import pandas as pd
import glob
import librosa 
from directory_tree import display_tree
path = r'/Users/frankconway/OneDrive/Strathclyde/Strathclyde/LadyCurranInternship/SVD/Data/'

# %%
def windows(audio, window_size):
    start = 0
    while start < len(audio):
        #len(audio) is the total number of sample points for an audio file.
        yield start, int(start) + window_size # Retrieve the sample point index index of length window_size
        start += (window_size / 2) #Calculate the starting position of the next segment

# %%
extracted_features_hel = pd.DataFrame(columns=['features','label','names','classification'])
extracted_features_ben = pd.DataFrame(columns=['features','label','names','classification'])
extracted_features_mal = pd.DataFrame(columns=['features','label','names','classification'])

def extract_features(parent_dir,sub_dirs,label,file_ext="*.wav",bands = 60, frames = 41):
    '''Wrangle audio data into 60x41x2 frames.
    Bands = 60 = number of MFCC
    frames = 41 = number of windows from the audio signal
    Number of channels (like R,G,B channels in images) = 2 = mel-
    spectrograms and their corresponding delta'''
    #
    
    window_size = 512 * (frames - 1) 
    log_specgrams = []
    labels = []
    names = []

    for l, sub_dir in enumerate(sub_dirs):
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)): 
            #if "phrase" in fn : continue # only train on vowels
            sound_clip,s = librosa.load(fn)
            
            for (start,end) in windows(sound_clip,window_size):
                    
                feature = []
                start = int(start)
                end = int(end)
                #print(start, end)
                #print(type(start), start, type(end), end, window_size)
                if(len(sound_clip[start:end]) == window_size):
                    names.append(fn.replace(path,''))
                    
                    signal = sound_clip[start:end] # window the original audio
                    D = np.abs(librosa.stft(signal))**2
                    melspec = librosa.feature.melspectrogram(S=D, n_mels = bands) # length 0f 60
                    #print('melspec:', len(melspec))
                    logspec = librosa.amplitude_to_db(melspec) # length 0f 60 & normalized
                    #print('logspec:', len(logspec))
                    #logspec = logspec.T.flatten()[:, np.newaxis].T # Transposed list of MFCCs
                    #print('logspec final:', len(logspec)) 
                    feature.append(logspec)
                    
                    melspec = librosa.feature.melspectrogram(y=signal, n_mels = bands)
                    logspec = librosa.amplitude_to_db(melspec) 
                    #logspec = logspec.T.flatten()[:, np.newaxis].T 
                    feature.append(logspec)
                    
                    melspec = librosa.feature.mfcc(y=signal, sr=s, n_mfcc=bands) 
                    logspec = librosa.amplitude_to_db(melspec)
                    #logspec = logspec.T.flatten()[:, np.newaxis].T 
                    #print(feature)
                    feature.append(logspec)
                                     
                    # use perceptual linear prediction cepstral features (PLPs) 
                    log_specgrams.append(feature)
                    labels.append(label)
                  
    for i in range (0, len(log_specgrams)):
        log_specgrams[i] = np.array(log_specgrams[i])
        log_specgrams[i] = np.transpose(log_specgrams[i], (1, 2, 0))
                  
    data = { 'features' : log_specgrams,
            'label': labels,
            'names' : names
           }
    df = pd.DataFrame(data , columns=['features','label','names'])
    return df

# %%
## Data should be stored in directory fromat 
display_tree(path,max_depth=1)
display_tree(path+'/Structural',max_depth=1)
# Out:
# Data/
# ├── Functional/
# ├── Healthy/
# ├── Neurological/
# ├── Other/
# ├── Pathology/
# └── Structural/
# Structural/
# ├── Arytenoid_Subluxation/
# ├── Carcinoma_in_situ/
# ├── Chondrom/
# ├── cordotomy/
# ├── Cyst/
# ├── Epiglottis_carcinoma/
# ├── fibroma/
# ├── fistula/
# ├── frontolateral_partial_laryngectomy/
# ├── Granuloma/
# ├── hyperplasia/
# ├── hypopharynx_cancer/
# ├── intubation_damage/
# ├── intubation_granuloma/
# ├── laryngeal_tumor/
# ├── Medial_cervical_cyst/
# ├── nasopharyngeal_tumor/
# ├── Papilloma/
# ├── pocket_wrinkled_voice/
# ├── Rhinophonia_closed/
# ├── Rhinophonia_mixed/
# ├── Rhinophonia_open/
# ├── Vallecular_Cyst/
# ├── Velo_pharyngoplasty/
# ├── vocal_cord_polyp/
# └── vocal_fold_carcinoma/

# %%
## load all data 

benign = ['Arytenoid_Subluxation','intubation_damage','fistula','Rhinophonia_closed', 
             'Rhinophonia_mixed','Rhinophonia_open','pocket_wrinkled_voice',
             'Vallecular_Cyst', 'Velo_pharyngoplasty' , 'Cyst','Medial_cervical_cyst',
            'hyperplasia','vocal_cord_polyp']


malignant = ['fibroma','nasopharyngeal_tumor','Carcinoma_in_situ','Chondrom','Epiglottis_carcinoma',
       'hypopharynx_cancer','laryngeal_tumor', 'Papilloma']


#path = r"/SVD/Data/"

extracted_features_hel = extract_features(path, ["Healthy"],0)
extracted_features_ben = extract_features(path+"Structural", benign,1)
extracted_features_mal = extract_features(path+"Structural", malignant,2)

# %%
if len(extracted_features_ben) > len(extracted_features_mal):
    size = len(extracted_features_mal)
else:
    size = len(extracted_features_ben)

# %%
extracted_features_mal
# Out:
#                                               features  label  \
# 0    [[[7.9065113, 7.9065113, 49.979515], [13.56918...      1
# 1    [[[-19.338318, -19.338318, 53.457497], [-17.05...      1
# 2    [[[2.5532827, 2.5532827, 42.685364], [-2.80675...      1
# 3    [[[-10.462711, -10.462711, 51.537453], [0.8124...      1
# 4    [[[-5.1042185, -5.1042185, 52.849346], [-3.951...      1
# ..                                                 ...    ...
# 308  [[[-1.1555995, -1.1555995, 46.35666], [-14.249...      1
# 309  [[[-3.69942, -3.69942, 44.41871], [-11.206899,...      1
# 310  [[[-3.9826603, -3.9826603, 49.77535], [-15.280...      1
# 311  [[[-9.667046, -9.667046, 44.95573], [-15.85511...      1
# 312  [[[-3.3811605, -3.3811605, 41.029648], [-6.617...      1
#
#                                    names
# 0         Structural/fibroma/106-u_n.wav
# 1     Structural/fibroma/1781-phrase.wav
# 2     Structural/fibroma/1781-phrase.wav
# 3     Structural/fibroma/1781-phrase.wav
# 4         Structural/fibroma/106-u_l.wav
# ..                                   ...
# 308    Structural/Papilloma/2529-u_l.wav
# 309  Structural/Papilloma/2529-u_lhl.wav
# 310    Structural/Papilloma/2529-u_n.wav
# 311  Structural/Papilloma/2529-i_lhl.wav
# 312  Structural/Papilloma/2529-a_lhl.wav
#
# [313 rows x 3 columns]

# %%
## change values to 1 for Hel or Ben/Mal
## 2 for Hel or Ben or Mal 

temp = [0]*len(extracted_features_ben)

extracted_features_ben['label'] = temp

temp = [1]*len(extracted_features_mal)

extracted_features_mal['label'] = temp

# %%
## split data to train, val, test 
## X and y from features and lables
## X to list them to np array for training 
## create y matrix for training output

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

## creating train/test/val for all df
## all training will have same data in train/test/val

train_hel, test_hel = train_test_split(extracted_features_hel[:size], test_size=0.2 , random_state=42)
train_ben, test_ben = train_test_split(extracted_features_ben[:size], test_size=0.2 , random_state=42)
train_mal, test_mal = train_test_split(extracted_features_mal[:size], test_size=0.2 , random_state=42)


val_hel, test_hel = train_test_split(test_hel, test_size = 0.5,random_state=42)
val_ben, test_ben = train_test_split(test_ben, test_size = 0.5,random_state=42)
val_mal, test_mal = train_test_split(test_mal, test_size = 0.5,random_state=42)

## stage 0 & 1

# train = pd.concat([train_hel,train_ben,train_mal])
# test = pd.concat([test_hel,test_ben,test_mal])
# val = pd.concat([val_hel,val_ben,val_mal])

## stage 2

train = pd.concat([train_ben,train_mal])
test = pd.concat([test_ben,test_mal])
val = pd.concat([val_ben,val_mal])

# train = pd.concat([train_hel,train_ben])
# test = pd.concat([test_hel,test_ben])
# val = pd.concat([val_hel,val_ben])

# train = pd.concat([train_hel,train_mal])
# test = pd.concat([test_hel,test_mal])
# val = pd.concat([val_hel,val_mal])

print("train: ",len(train))
print("val: ", len(val))
print("test: ", len(test))

labelencoder=LabelEncoder()

X_train = train['features'].to_list()
X_val = val['features'].to_list()
X_test = test['features'].to_list()
X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

y_train = train['label']
y_test = test['label']
y_val = val['label']
y_train = to_categorical(labelencoder.fit_transform(train['label']))
y_val = to_categorical(labelencoder.fit_transform(val['label']))
y_test = to_categorical(labelencoder.fit_transform(test['label']))

names_val = val['names']
# Out:
# train:  500
# val:  62
# test:  64

# %%
print("X shape: ", X_test.shape)
# Out:
# X shape:  (64, 60, 41, 3)

# %%
## training Stage 
## stage 0 = Healthy / Malignant/ Benign => num_classes = 3
## stage 1 = Healthy / Malignant&Benign  => num_classes = 2
## stage 2 = Malignant / Benign          => num_classes = 2

num_classes = 2
stage = 'Test/Stage2/'

# %%
import tensorflow as tf
import keras

# METRICS = [
#       keras.metrics.BinaryCrossentropy(name='cross entropy'),  # same as model's loss
#       keras.metrics.MeanSquaredError(name='Brier score'),
#       keras.metrics.TruePositives(name='tp'),
#       keras.metrics.FalsePositives(name='fp'),
#       keras.metrics.TrueNegatives(name='tn'),
#       keras.metrics.FalseNegatives(name='fn'), 
#       keras.metrics.BinaryAccuracy(name='accuracy'),
#       keras.metrics.Precision(name='precision'),
#       keras.metrics.Recall(name='recall'),
#       keras.metrics.AUC(name='auc'),
#       keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
# ]

# %%
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,BatchNormalization
from tensorflow.keras.layers import Activation,MaxPooling2D,LeakyReLU


model = keras.Sequential()

# Layer 1 - Convolution with 24 filters + Maxpooling
model.add(Conv2D(64, (3,3), padding='valid', 
                input_shape=(60,41,3), strides=(1, 1)
                 ,kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2),
                       strides=(2, 2))) 

model.add(BatchNormalization(axis=1)) 
model.add(Dropout(0.5))
model.add(Activation('tanh'))

# Layer 2 - Convolution with 48 filters + Maxpooling 
model.add(Conv2D(64, (3,3)
                       ,kernel_regularizer=keras.regularizers.l2(0.001))) 
model.add(MaxPooling2D(pool_size=(2, 2),strides=(2, 2))) 
model.add(BatchNormalization(axis=1)) 
model.add(Dropout(0.5))
#model.add(Activation('relu'))
model.add(LeakyReLU(alpha=0.03))


# Layer 3 - Convolution with 24 filters + Maxpooling
model.add(Conv2D(64, (3,3), padding='valid',
                 ))
model.add(BatchNormalization(axis=1)) 
model.add(Dropout(0.5))
#model.add(Activation('relu'))
model.add(LeakyReLU(alpha=0.03))



model.add(layers.Flatten())
model.add(Dense(units=64, activation='LeakyReLU'))
model.add(Dense(units=num_classes, activation='sigmoid'))

# Model compilation
opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy',
                metrics=['categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 58, 39, 64)        1792
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 19, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 29, 19, 64)       116
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 29, 19, 64)        0
#
#  activation_1 (Activation)   (None, 29, 19, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 27, 17, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 8, 64)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 13, 8, 64)        52
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 13, 8, 64)         0
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 13, 8, 64)         0
#
#  conv2d_5 (Conv2D)           (None, 11, 6, 64)         36928
#
#  batch_normalization_5 (Batc  (None, 11, 6, 64)        44
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 11, 6, 64)         0
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 11, 6, 64)         0
#
#  flatten_1 (Flatten)         (None, 4224)              0
#
#  dense_2 (Dense)             (None, 64)                270400
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 346,390
# Trainable params: 346,284
# Non-trainable params: 106
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from datetime import datetime 

num_epochs = 1000
num_batch_size = 64

checkpointer = ModelCheckpoint(filepath=stage+'/CNN.hdf5', 
                               verbose=1,monitor='val_categorical_accuracy', save_best_only=True)
early = EarlyStopping(
    monitor='val_categorical_accuracy', 
    verbose=1,
    patience=100,
    mode='max',
    restore_best_weights=True)
start = datetime.now()

hist = model.fit(X_train,y_train , batch_size=num_batch_size, epochs=num_epochs, 
                 validation_data=(X_val, y_val), callbacks=[checkpointer,early], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - ETA: 0s - loss: 1.3536 - categorical_accuracy: 0.5000
# Epoch 1: val_categorical_accuracy improved from -inf to 0.50000, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 1s 54ms/step - loss: 1.3536 - categorical_accuracy: 0.5000 - val_loss: 1.1985 - val_categorical_accuracy: 0.5000
# Epoch 2/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.9623 - categorical_accuracy: 0.5268
# Epoch 2: val_categorical_accuracy did not improve from 0.50000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9416 - categorical_accuracy: 0.5340 - val_loss: 0.9454 - val_categorical_accuracy: 0.5000
# Epoch 3/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8402 - categorical_accuracy: 0.5045
# Epoch 3: val_categorical_accuracy improved from 0.50000 to 0.61290, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8333 - categorical_accuracy: 0.5080 - val_loss: 0.7541 - val_categorical_accuracy: 0.6129
# Epoch 4/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7856 - categorical_accuracy: 0.5625
# Epoch 4: val_categorical_accuracy did not improve from 0.61290
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7817 - categorical_accuracy: 0.5600 - val_loss: 0.7263 - val_categorical_accuracy: 0.5806
# Epoch 5/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7379 - categorical_accuracy: 0.5893
# Epoch 5: val_categorical_accuracy improved from 0.61290 to 0.62903, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7404 - categorical_accuracy: 0.5900 - val_loss: 0.7115 - val_categorical_accuracy: 0.6290
# Epoch 6/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.7387 - categorical_accuracy: 0.6200
# Epoch 6: val_categorical_accuracy improved from 0.62903 to 0.64516, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7387 - categorical_accuracy: 0.6200 - val_loss: 0.7330 - val_categorical_accuracy: 0.6452
# Epoch 7/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7371 - categorical_accuracy: 0.6116
# Epoch 7: val_categorical_accuracy did not improve from 0.64516
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7390 - categorical_accuracy: 0.6140 - val_loss: 0.7361 - val_categorical_accuracy: 0.6129
# Epoch 8/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6894 - categorical_accuracy: 0.6540
# Epoch 8: val_categorical_accuracy did not improve from 0.64516
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6846 - categorical_accuracy: 0.6580 - val_loss: 0.7298 - val_categorical_accuracy: 0.5968
# Epoch 9/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7024 - categorical_accuracy: 0.6384
# Epoch 9: val_categorical_accuracy did not improve from 0.64516
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6927 - categorical_accuracy: 0.6520 - val_loss: 0.6539 - val_categorical_accuracy: 0.6452
# Epoch 10/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7154 - categorical_accuracy: 0.6205
# Epoch 10: val_categorical_accuracy did not improve from 0.64516
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7092 - categorical_accuracy: 0.6260 - val_loss: 0.6213 - val_categorical_accuracy: 0.6452
# Epoch 11/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6993 - categorical_accuracy: 0.6406
# Epoch 11: val_categorical_accuracy improved from 0.64516 to 0.72581, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6873 - categorical_accuracy: 0.6520 - val_loss: 0.5917 - val_categorical_accuracy: 0.7258
# Epoch 12/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6673 - categorical_accuracy: 0.6853
# Epoch 12: val_categorical_accuracy did not improve from 0.72581
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6586 - categorical_accuracy: 0.6980 - val_loss: 0.5856 - val_categorical_accuracy: 0.7097
# Epoch 13/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6060 - categorical_accuracy: 0.7188
# Epoch 13: val_categorical_accuracy improved from 0.72581 to 0.75806, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5968 - categorical_accuracy: 0.7300 - val_loss: 0.5046 - val_categorical_accuracy: 0.7581
# Epoch 14/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5465 - categorical_accuracy: 0.7589
# Epoch 14: val_categorical_accuracy did not improve from 0.75806
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5511 - categorical_accuracy: 0.7600 - val_loss: 0.5367 - val_categorical_accuracy: 0.7581
# Epoch 15/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.5654 - categorical_accuracy: 0.7660
# Epoch 15: val_categorical_accuracy improved from 0.75806 to 0.85484, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5654 - categorical_accuracy: 0.7660 - val_loss: 0.4896 - val_categorical_accuracy: 0.8548
# Epoch 16/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4928 - categorical_accuracy: 0.7800
# Epoch 16: val_categorical_accuracy did not improve from 0.85484
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4928 - categorical_accuracy: 0.7800 - val_loss: 0.4520 - val_categorical_accuracy: 0.8065
# Epoch 17/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4613 - categorical_accuracy: 0.8220
# Epoch 17: val_categorical_accuracy improved from 0.85484 to 0.87097, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4613 - categorical_accuracy: 0.8220 - val_loss: 0.4385 - val_categorical_accuracy: 0.8710
# Epoch 18/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4645 - categorical_accuracy: 0.8140
# Epoch 18: val_categorical_accuracy did not improve from 0.87097
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4645 - categorical_accuracy: 0.8140 - val_loss: 0.4265 - val_categorical_accuracy: 0.8548
# Epoch 19/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4856 - categorical_accuracy: 0.8214
# Epoch 19: val_categorical_accuracy improved from 0.87097 to 0.88710, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4881 - categorical_accuracy: 0.8180 - val_loss: 0.4224 - val_categorical_accuracy: 0.8871
# Epoch 20/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4210 - categorical_accuracy: 0.8504
# Epoch 20: val_categorical_accuracy improved from 0.88710 to 0.91935, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4258 - categorical_accuracy: 0.8420 - val_loss: 0.3476 - val_categorical_accuracy: 0.9194
# Epoch 21/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4045 - categorical_accuracy: 0.8560
# Epoch 21: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4045 - categorical_accuracy: 0.8560 - val_loss: 0.3828 - val_categorical_accuracy: 0.8387
# Epoch 22/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4406 - categorical_accuracy: 0.8360
# Epoch 22: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4406 - categorical_accuracy: 0.8360 - val_loss: 0.3854 - val_categorical_accuracy: 0.8710
# Epoch 23/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3329 - categorical_accuracy: 0.8660
# Epoch 23: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3329 - categorical_accuracy: 0.8660 - val_loss: 0.3475 - val_categorical_accuracy: 0.8548
# Epoch 24/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3174 - categorical_accuracy: 0.8940
# Epoch 24: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3174 - categorical_accuracy: 0.8940 - val_loss: 0.3707 - val_categorical_accuracy: 0.8710
# Epoch 25/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3230 - categorical_accuracy: 0.8980
# Epoch 25: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3230 - categorical_accuracy: 0.8980 - val_loss: 0.3597 - val_categorical_accuracy: 0.8871
# Epoch 26/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2875 - categorical_accuracy: 0.9129
# Epoch 26: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2956 - categorical_accuracy: 0.9080 - val_loss: 0.3946 - val_categorical_accuracy: 0.9032
# Epoch 27/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3080 - categorical_accuracy: 0.9040
# Epoch 27: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3101 - categorical_accuracy: 0.9020 - val_loss: 0.3250 - val_categorical_accuracy: 0.9032
# Epoch 28/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2723 - categorical_accuracy: 0.9200
# Epoch 28: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2723 - categorical_accuracy: 0.9200 - val_loss: 0.3101 - val_categorical_accuracy: 0.9032
# Epoch 29/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2736 - categorical_accuracy: 0.9196
# Epoch 29: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2709 - categorical_accuracy: 0.9180 - val_loss: 0.3965 - val_categorical_accuracy: 0.9194
# Epoch 30/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2545 - categorical_accuracy: 0.9196
# Epoch 30: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2567 - categorical_accuracy: 0.9240 - val_loss: 0.3804 - val_categorical_accuracy: 0.8871
# Epoch 31/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2619 - categorical_accuracy: 0.9220
# Epoch 31: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2619 - categorical_accuracy: 0.9220 - val_loss: 0.4416 - val_categorical_accuracy: 0.8871
# Epoch 32/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2632 - categorical_accuracy: 0.9020
# Epoch 32: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2632 - categorical_accuracy: 0.9020 - val_loss: 0.3738 - val_categorical_accuracy: 0.8871
# Epoch 33/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2229 - categorical_accuracy: 0.9440
# Epoch 33: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2229 - categorical_accuracy: 0.9440 - val_loss: 0.3367 - val_categorical_accuracy: 0.8871
# Epoch 34/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2274 - categorical_accuracy: 0.9330
# Epoch 34: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2269 - categorical_accuracy: 0.9340 - val_loss: 0.5258 - val_categorical_accuracy: 0.9032
# Epoch 35/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1959 - categorical_accuracy: 0.9600
# Epoch 35: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1959 - categorical_accuracy: 0.9600 - val_loss: 0.4561 - val_categorical_accuracy: 0.8871
# Epoch 36/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2337 - categorical_accuracy: 0.9240
# Epoch 36: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2337 - categorical_accuracy: 0.9240 - val_loss: 0.4140 - val_categorical_accuracy: 0.9032
# Epoch 37/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2108 - categorical_accuracy: 0.9464
# Epoch 37: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2118 - categorical_accuracy: 0.9420 - val_loss: 0.4284 - val_categorical_accuracy: 0.9032
# Epoch 38/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1866 - categorical_accuracy: 0.9520
# Epoch 38: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1866 - categorical_accuracy: 0.9520 - val_loss: 0.2829 - val_categorical_accuracy: 0.9194
# Epoch 39/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2033 - categorical_accuracy: 0.9580
# Epoch 39: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2033 - categorical_accuracy: 0.9580 - val_loss: 0.4311 - val_categorical_accuracy: 0.9032
# Epoch 40/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1951 - categorical_accuracy: 0.9464
# Epoch 40: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2068 - categorical_accuracy: 0.9420 - val_loss: 0.3845 - val_categorical_accuracy: 0.9032
# Epoch 41/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2003 - categorical_accuracy: 0.9442
# Epoch 41: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2168 - categorical_accuracy: 0.9380 - val_loss: 0.4070 - val_categorical_accuracy: 0.8871
# Epoch 42/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2073 - categorical_accuracy: 0.9460
# Epoch 42: val_categorical_accuracy did not improve from 0.91935
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2073 - categorical_accuracy: 0.9460 - val_loss: 0.4792 - val_categorical_accuracy: 0.8710
# Epoch 43/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2020 - categorical_accuracy: 0.9420
# Epoch 43: val_categorical_accuracy improved from 0.91935 to 0.93548, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2020 - categorical_accuracy: 0.9420 - val_loss: 0.3341 - val_categorical_accuracy: 0.9355
# Epoch 44/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1440 - categorical_accuracy: 0.9780
# Epoch 44: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1440 - categorical_accuracy: 0.9780 - val_loss: 0.3654 - val_categorical_accuracy: 0.9194
# Epoch 45/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1584 - categorical_accuracy: 0.9576
# Epoch 45: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1659 - categorical_accuracy: 0.9560 - val_loss: 0.5727 - val_categorical_accuracy: 0.8871
# Epoch 46/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1866 - categorical_accuracy: 0.9665
# Epoch 46: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1827 - categorical_accuracy: 0.9660 - val_loss: 0.3318 - val_categorical_accuracy: 0.9355
# Epoch 47/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1552 - categorical_accuracy: 0.9643
# Epoch 47: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1576 - categorical_accuracy: 0.9620 - val_loss: 0.3857 - val_categorical_accuracy: 0.9032
# Epoch 48/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1381 - categorical_accuracy: 0.9777
# Epoch 48: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1403 - categorical_accuracy: 0.9780 - val_loss: 0.7279 - val_categorical_accuracy: 0.8871
# Epoch 49/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1581 - categorical_accuracy: 0.9777
# Epoch 49: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1514 - categorical_accuracy: 0.9800 - val_loss: 0.3441 - val_categorical_accuracy: 0.9355
# Epoch 50/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1297 - categorical_accuracy: 0.9777
# Epoch 50: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1263 - categorical_accuracy: 0.9800 - val_loss: 0.7462 - val_categorical_accuracy: 0.8871
# Epoch 51/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1528 - categorical_accuracy: 0.9665
# Epoch 51: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1477 - categorical_accuracy: 0.9700 - val_loss: 0.5409 - val_categorical_accuracy: 0.8871
# Epoch 52/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1155 - categorical_accuracy: 0.9866
# Epoch 52: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1118 - categorical_accuracy: 0.9880 - val_loss: 0.6460 - val_categorical_accuracy: 0.8871
# Epoch 53/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1253 - categorical_accuracy: 0.9777
# Epoch 53: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1204 - categorical_accuracy: 0.9800 - val_loss: 0.4960 - val_categorical_accuracy: 0.9032
# Epoch 54/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1369 - categorical_accuracy: 0.9821
# Epoch 54: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1366 - categorical_accuracy: 0.9800 - val_loss: 0.3993 - val_categorical_accuracy: 0.9355
# Epoch 55/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1591 - categorical_accuracy: 0.9688
# Epoch 55: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1538 - categorical_accuracy: 0.9700 - val_loss: 0.4491 - val_categorical_accuracy: 0.9194
# Epoch 56/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1451 - categorical_accuracy: 0.9732
# Epoch 56: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1391 - categorical_accuracy: 0.9760 - val_loss: 0.3988 - val_categorical_accuracy: 0.9032
# Epoch 57/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1446 - categorical_accuracy: 0.9732
# Epoch 57: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1474 - categorical_accuracy: 0.9700 - val_loss: 0.4937 - val_categorical_accuracy: 0.9032
# Epoch 58/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1138 - categorical_accuracy: 0.9820
# Epoch 58: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1138 - categorical_accuracy: 0.9820 - val_loss: 0.5238 - val_categorical_accuracy: 0.9032
# Epoch 59/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1390 - categorical_accuracy: 0.9710
# Epoch 59: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1485 - categorical_accuracy: 0.9700 - val_loss: 0.4887 - val_categorical_accuracy: 0.9032
# Epoch 60/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1169 - categorical_accuracy: 0.9800
# Epoch 60: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1169 - categorical_accuracy: 0.9800 - val_loss: 0.4760 - val_categorical_accuracy: 0.9032
# Epoch 61/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1185 - categorical_accuracy: 0.9780
# Epoch 61: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1185 - categorical_accuracy: 0.9780 - val_loss: 0.4426 - val_categorical_accuracy: 0.9032
# Epoch 62/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1213 - categorical_accuracy: 0.9844
# Epoch 62: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1245 - categorical_accuracy: 0.9820 - val_loss: 0.5153 - val_categorical_accuracy: 0.9194
# Epoch 63/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1265 - categorical_accuracy: 0.9821
# Epoch 63: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1307 - categorical_accuracy: 0.9800 - val_loss: 0.5589 - val_categorical_accuracy: 0.9032
# Epoch 64/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1189 - categorical_accuracy: 0.9840
# Epoch 64: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1189 - categorical_accuracy: 0.9840 - val_loss: 0.3942 - val_categorical_accuracy: 0.9355
# Epoch 65/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1352 - categorical_accuracy: 0.9754
# Epoch 65: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1300 - categorical_accuracy: 0.9780 - val_loss: 0.7459 - val_categorical_accuracy: 0.9032
# Epoch 66/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1260 - categorical_accuracy: 0.9799
# Epoch 66: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1225 - categorical_accuracy: 0.9820 - val_loss: 0.4896 - val_categorical_accuracy: 0.9032
# Epoch 67/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1065 - categorical_accuracy: 0.9866
# Epoch 67: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1071 - categorical_accuracy: 0.9860 - val_loss: 0.6572 - val_categorical_accuracy: 0.9032
# Epoch 68/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0923 - categorical_accuracy: 0.9911
# Epoch 68: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0908 - categorical_accuracy: 0.9920 - val_loss: 0.5786 - val_categorical_accuracy: 0.8871
# Epoch 69/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1073 - categorical_accuracy: 0.9860
# Epoch 69: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1073 - categorical_accuracy: 0.9860 - val_loss: 0.3868 - val_categorical_accuracy: 0.9032
# Epoch 70/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1274 - categorical_accuracy: 0.9799
# Epoch 70: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1307 - categorical_accuracy: 0.9800 - val_loss: 0.3367 - val_categorical_accuracy: 0.9194
# Epoch 71/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0996 - categorical_accuracy: 0.9844
# Epoch 71: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1012 - categorical_accuracy: 0.9820 - val_loss: 0.3197 - val_categorical_accuracy: 0.9355
# Epoch 72/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1168 - categorical_accuracy: 0.9840
# Epoch 72: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1168 - categorical_accuracy: 0.9840 - val_loss: 0.6480 - val_categorical_accuracy: 0.9194
# Epoch 73/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1130 - categorical_accuracy: 0.9840
# Epoch 73: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1130 - categorical_accuracy: 0.9840 - val_loss: 0.2908 - val_categorical_accuracy: 0.9355
# Epoch 74/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1379 - categorical_accuracy: 0.9777
# Epoch 74: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1390 - categorical_accuracy: 0.9740 - val_loss: 0.5908 - val_categorical_accuracy: 0.9194
# Epoch 75/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1012 - categorical_accuracy: 0.9860
# Epoch 75: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1012 - categorical_accuracy: 0.9860 - val_loss: 0.4445 - val_categorical_accuracy: 0.9194
# Epoch 76/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1022 - categorical_accuracy: 0.9900
# Epoch 76: val_categorical_accuracy did not improve from 0.93548
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1022 - categorical_accuracy: 0.9900 - val_loss: 0.4173 - val_categorical_accuracy: 0.9355
# Epoch 77/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0897 - categorical_accuracy: 0.9933
# Epoch 77: val_categorical_accuracy improved from 0.93548 to 0.95161, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1011 - categorical_accuracy: 0.9880 - val_loss: 0.2895 - val_categorical_accuracy: 0.9516
# Epoch 78/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0945 - categorical_accuracy: 0.9940
# Epoch 78: val_categorical_accuracy did not improve from 0.95161
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0945 - categorical_accuracy: 0.9940 - val_loss: 0.5242 - val_categorical_accuracy: 0.9194
# Epoch 79/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0997 - categorical_accuracy: 0.9866
# Epoch 79: val_categorical_accuracy improved from 0.95161 to 0.96774, saving model to Test/Stage2/CNN.hdf5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0967 - categorical_accuracy: 0.9880 - val_loss: 0.2586 - val_categorical_accuracy: 0.9677
# Epoch 80/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0997 - categorical_accuracy: 0.9866
# Epoch 80: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1071 - categorical_accuracy: 0.9820 - val_loss: 0.3380 - val_categorical_accuracy: 0.9355
# Epoch 81/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0978 - categorical_accuracy: 0.9880
# Epoch 81: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0978 - categorical_accuracy: 0.9880 - val_loss: 0.5342 - val_categorical_accuracy: 0.9032
# Epoch 82/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0904 - categorical_accuracy: 0.9900
# Epoch 82: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0904 - categorical_accuracy: 0.9900 - val_loss: 0.5069 - val_categorical_accuracy: 0.9355
# Epoch 83/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0841 - categorical_accuracy: 0.9955
# Epoch 83: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0831 - categorical_accuracy: 0.9960 - val_loss: 0.3272 - val_categorical_accuracy: 0.9516
# Epoch 84/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1118 - categorical_accuracy: 0.9844
# Epoch 84: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1077 - categorical_accuracy: 0.9860 - val_loss: 0.3102 - val_categorical_accuracy: 0.9355
# Epoch 85/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1052 - categorical_accuracy: 0.9821
# Epoch 85: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1015 - categorical_accuracy: 0.9840 - val_loss: 0.4986 - val_categorical_accuracy: 0.9194
# Epoch 86/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0903 - categorical_accuracy: 0.9933
# Epoch 86: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0920 - categorical_accuracy: 0.9920 - val_loss: 0.8548 - val_categorical_accuracy: 0.9032
# Epoch 87/1000
# 5/8 [=================>............] - ETA: 0s - loss: 0.1031 - categorical_accuracy: 0.9906
# Epoch 87: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1158 - categorical_accuracy: 0.9920 - val_loss: 0.7537 - val_categorical_accuracy: 0.9032
# Epoch 88/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1040 - categorical_accuracy: 0.9800
# Epoch 88: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1040 - categorical_accuracy: 0.9800 - val_loss: 0.8269 - val_categorical_accuracy: 0.9032
# Epoch 89/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1177 - categorical_accuracy: 0.9866
# Epoch 89: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1142 - categorical_accuracy: 0.9880 - val_loss: 0.5330 - val_categorical_accuracy: 0.9032
# Epoch 90/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1243 - categorical_accuracy: 0.9732
# Epoch 90: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1211 - categorical_accuracy: 0.9740 - val_loss: 0.9077 - val_categorical_accuracy: 0.8871
# Epoch 91/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1201 - categorical_accuracy: 0.9844
# Epoch 91: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1278 - categorical_accuracy: 0.9820 - val_loss: 0.8505 - val_categorical_accuracy: 0.9032
# Epoch 92/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1260 - categorical_accuracy: 0.9799
# Epoch 92: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1263 - categorical_accuracy: 0.9800 - val_loss: 0.7910 - val_categorical_accuracy: 0.9355
# Epoch 93/1000
# 5/8 [=================>............] - ETA: 0s - loss: 0.0884 - categorical_accuracy: 0.9875
# Epoch 93: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1037 - categorical_accuracy: 0.9780 - val_loss: 0.8483 - val_categorical_accuracy: 0.9194
# Epoch 94/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1013 - categorical_accuracy: 0.9840
# Epoch 94: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1013 - categorical_accuracy: 0.9840 - val_loss: 0.8003 - val_categorical_accuracy: 0.9032
# Epoch 95/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1020 - categorical_accuracy: 0.9920
# Epoch 95: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1020 - categorical_accuracy: 0.9920 - val_loss: 0.6111 - val_categorical_accuracy: 0.8871
# Epoch 96/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1130 - categorical_accuracy: 0.9799
# Epoch 96: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1103 - categorical_accuracy: 0.9820 - val_loss: 0.6611 - val_categorical_accuracy: 0.9194
# Epoch 97/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0956 - categorical_accuracy: 0.9880
# Epoch 97: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0956 - categorical_accuracy: 0.9880 - val_loss: 0.5203 - val_categorical_accuracy: 0.9194
# Epoch 98/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0932 - categorical_accuracy: 0.9911
# Epoch 98: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0929 - categorical_accuracy: 0.9920 - val_loss: 0.5610 - val_categorical_accuracy: 0.9194
# Epoch 99/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1047 - categorical_accuracy: 0.9900
# Epoch 99: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1047 - categorical_accuracy: 0.9900 - val_loss: 0.4810 - val_categorical_accuracy: 0.9032
# Epoch 100/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0890 - categorical_accuracy: 0.9911
# Epoch 100: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0885 - categorical_accuracy: 0.9920 - val_loss: 0.5922 - val_categorical_accuracy: 0.9032
# Epoch 101/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0901 - categorical_accuracy: 0.9880
# Epoch 101: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0901 - categorical_accuracy: 0.9880 - val_loss: 0.7153 - val_categorical_accuracy: 0.9032
# Epoch 102/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1026 - categorical_accuracy: 0.9888
# Epoch 102: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0990 - categorical_accuracy: 0.9900 - val_loss: 0.6143 - val_categorical_accuracy: 0.9194
# Epoch 103/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0846 - categorical_accuracy: 0.9933
# Epoch 103: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0829 - categorical_accuracy: 0.9940 - val_loss: 0.5720 - val_categorical_accuracy: 0.9194
# Epoch 104/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0761 - categorical_accuracy: 1.0000
# Epoch 104: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0767 - categorical_accuracy: 1.0000 - val_loss: 0.6691 - val_categorical_accuracy: 0.9194
# Epoch 105/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0767 - categorical_accuracy: 0.9960
# Epoch 105: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0767 - categorical_accuracy: 0.9960 - val_loss: 0.9174 - val_categorical_accuracy: 0.9032
# Epoch 106/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0923 - categorical_accuracy: 0.9900
# Epoch 106: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0923 - categorical_accuracy: 0.9900 - val_loss: 0.7598 - val_categorical_accuracy: 0.9194
# Epoch 107/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0823 - categorical_accuracy: 0.9955
# Epoch 107: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0818 - categorical_accuracy: 0.9960 - val_loss: 0.6644 - val_categorical_accuracy: 0.9355
# Epoch 108/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1223 - categorical_accuracy: 0.9799
# Epoch 108: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1165 - categorical_accuracy: 0.9820 - val_loss: 0.6914 - val_categorical_accuracy: 0.9032
# Epoch 109/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0904 - categorical_accuracy: 0.9940
# Epoch 109: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0904 - categorical_accuracy: 0.9940 - val_loss: 0.6691 - val_categorical_accuracy: 0.9194
# Epoch 110/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0813 - categorical_accuracy: 0.9911
# Epoch 110: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0805 - categorical_accuracy: 0.9920 - val_loss: 0.9622 - val_categorical_accuracy: 0.9194
# Epoch 111/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0989 - categorical_accuracy: 0.9866
# Epoch 111: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0965 - categorical_accuracy: 0.9880 - val_loss: 0.6779 - val_categorical_accuracy: 0.9032
# Epoch 112/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0716 - categorical_accuracy: 1.0000
# Epoch 112: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0710 - categorical_accuracy: 1.0000 - val_loss: 0.6704 - val_categorical_accuracy: 0.9032
# Epoch 113/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0783 - categorical_accuracy: 0.9940
# Epoch 113: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0783 - categorical_accuracy: 0.9940 - val_loss: 0.6606 - val_categorical_accuracy: 0.9032
# Epoch 114/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0740 - categorical_accuracy: 0.9960
# Epoch 114: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0740 - categorical_accuracy: 0.9960 - val_loss: 0.6957 - val_categorical_accuracy: 0.9194
# Epoch 115/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0774 - categorical_accuracy: 0.9955
# Epoch 115: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0762 - categorical_accuracy: 0.9960 - val_loss: 0.7099 - val_categorical_accuracy: 0.9194
# Epoch 116/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0725 - categorical_accuracy: 0.9980
# Epoch 116: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0725 - categorical_accuracy: 0.9980 - val_loss: 0.6329 - val_categorical_accuracy: 0.9194
# Epoch 117/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0767 - categorical_accuracy: 0.9960
# Epoch 117: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0767 - categorical_accuracy: 0.9960 - val_loss: 0.5711 - val_categorical_accuracy: 0.9194
# Epoch 118/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0700 - categorical_accuracy: 0.9978
# Epoch 118: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0695 - categorical_accuracy: 0.9980 - val_loss: 0.5923 - val_categorical_accuracy: 0.9194
# Epoch 119/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0811 - categorical_accuracy: 0.9960
# Epoch 119: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0811 - categorical_accuracy: 0.9960 - val_loss: 0.6628 - val_categorical_accuracy: 0.9355
# Epoch 120/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0833 - categorical_accuracy: 0.9980
# Epoch 120: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0833 - categorical_accuracy: 0.9980 - val_loss: 0.8536 - val_categorical_accuracy: 0.9194
# Epoch 121/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0850 - categorical_accuracy: 0.9960
# Epoch 121: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0850 - categorical_accuracy: 0.9960 - val_loss: 0.9261 - val_categorical_accuracy: 0.9194
# Epoch 122/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0784 - categorical_accuracy: 0.9940
# Epoch 122: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0784 - categorical_accuracy: 0.9940 - val_loss: 0.8454 - val_categorical_accuracy: 0.9194
# Epoch 123/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0717 - categorical_accuracy: 0.9978
# Epoch 123: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0718 - categorical_accuracy: 0.9980 - val_loss: 0.9086 - val_categorical_accuracy: 0.9194
# Epoch 124/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0721 - categorical_accuracy: 0.9955
# Epoch 124: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0721 - categorical_accuracy: 0.9960 - val_loss: 0.6204 - val_categorical_accuracy: 0.9355
# Epoch 125/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0677 - categorical_accuracy: 1.0000
# Epoch 125: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0727 - categorical_accuracy: 0.9980 - val_loss: 0.6308 - val_categorical_accuracy: 0.9355
# Epoch 126/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0733 - categorical_accuracy: 0.9933
# Epoch 126: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0724 - categorical_accuracy: 0.9940 - val_loss: 0.5979 - val_categorical_accuracy: 0.9355
# Epoch 127/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0700 - categorical_accuracy: 0.9978
# Epoch 127: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0762 - categorical_accuracy: 0.9960 - val_loss: 0.5309 - val_categorical_accuracy: 0.9355
# Epoch 128/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0683 - categorical_accuracy: 0.9980
# Epoch 128: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0683 - categorical_accuracy: 0.9980 - val_loss: 0.5467 - val_categorical_accuracy: 0.9355
# Epoch 129/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0796 - categorical_accuracy: 0.9978
# Epoch 129: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0783 - categorical_accuracy: 0.9980 - val_loss: 0.5058 - val_categorical_accuracy: 0.9355
# Epoch 130/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0773 - categorical_accuracy: 0.9955
# Epoch 130: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0757 - categorical_accuracy: 0.9960 - val_loss: 0.6392 - val_categorical_accuracy: 0.9194
# Epoch 131/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0681 - categorical_accuracy: 0.9960
# Epoch 131: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0681 - categorical_accuracy: 0.9960 - val_loss: 0.4932 - val_categorical_accuracy: 0.9194
# Epoch 132/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0676 - categorical_accuracy: 0.9960
# Epoch 132: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0676 - categorical_accuracy: 0.9960 - val_loss: 0.7716 - val_categorical_accuracy: 0.9032
# Epoch 133/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0654 - categorical_accuracy: 1.0000
# Epoch 133: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0654 - categorical_accuracy: 1.0000 - val_loss: 0.8060 - val_categorical_accuracy: 0.9032
# Epoch 134/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0665 - categorical_accuracy: 0.9978
# Epoch 134: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0659 - categorical_accuracy: 0.9980 - val_loss: 0.8122 - val_categorical_accuracy: 0.9194
# Epoch 135/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0899 - categorical_accuracy: 0.9866
# Epoch 135: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0883 - categorical_accuracy: 0.9880 - val_loss: 0.9784 - val_categorical_accuracy: 0.9194
# Epoch 136/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0799 - categorical_accuracy: 0.9888
# Epoch 136: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0828 - categorical_accuracy: 0.9880 - val_loss: 0.7264 - val_categorical_accuracy: 0.9194
# Epoch 137/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0801 - categorical_accuracy: 0.9911
# Epoch 137: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0781 - categorical_accuracy: 0.9920 - val_loss: 0.7577 - val_categorical_accuracy: 0.9194
# Epoch 138/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0782 - categorical_accuracy: 0.9900
# Epoch 138: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0782 - categorical_accuracy: 0.9900 - val_loss: 0.7023 - val_categorical_accuracy: 0.9194
# Epoch 139/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0666 - categorical_accuracy: 1.0000
# Epoch 139: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0666 - categorical_accuracy: 1.0000 - val_loss: 0.8429 - val_categorical_accuracy: 0.9194
# Epoch 140/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0722 - categorical_accuracy: 0.9960
# Epoch 140: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0722 - categorical_accuracy: 0.9960 - val_loss: 0.6758 - val_categorical_accuracy: 0.9194
# Epoch 141/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0793 - categorical_accuracy: 0.9911
# Epoch 141: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0821 - categorical_accuracy: 0.9900 - val_loss: 1.2293 - val_categorical_accuracy: 0.9032
# Epoch 142/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0807 - categorical_accuracy: 0.9933
# Epoch 142: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0790 - categorical_accuracy: 0.9940 - val_loss: 0.9220 - val_categorical_accuracy: 0.9194
# Epoch 143/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0715 - categorical_accuracy: 0.9978
# Epoch 143: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0779 - categorical_accuracy: 0.9920 - val_loss: 0.9640 - val_categorical_accuracy: 0.9194
# Epoch 144/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0910 - categorical_accuracy: 0.9880
# Epoch 144: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0910 - categorical_accuracy: 0.9880 - val_loss: 1.0179 - val_categorical_accuracy: 0.9194
# Epoch 145/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0761 - categorical_accuracy: 0.9920
# Epoch 145: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0761 - categorical_accuracy: 0.9920 - val_loss: 0.9575 - val_categorical_accuracy: 0.9032
# Epoch 146/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0744 - categorical_accuracy: 0.9920
# Epoch 146: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0744 - categorical_accuracy: 0.9920 - val_loss: 0.9923 - val_categorical_accuracy: 0.9194
# Epoch 147/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0804 - categorical_accuracy: 0.9866
# Epoch 147: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0783 - categorical_accuracy: 0.9880 - val_loss: 0.9408 - val_categorical_accuracy: 0.9194
# Epoch 148/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0774 - categorical_accuracy: 0.9960
# Epoch 148: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0774 - categorical_accuracy: 0.9960 - val_loss: 0.7694 - val_categorical_accuracy: 0.9355
# Epoch 149/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0793 - categorical_accuracy: 0.9888
# Epoch 149: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0779 - categorical_accuracy: 0.9900 - val_loss: 1.1889 - val_categorical_accuracy: 0.9355
# Epoch 150/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0843 - categorical_accuracy: 0.9900
# Epoch 150: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0843 - categorical_accuracy: 0.9900 - val_loss: 0.9535 - val_categorical_accuracy: 0.9032
# Epoch 151/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1066 - categorical_accuracy: 0.9777
# Epoch 151: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1108 - categorical_accuracy: 0.9760 - val_loss: 0.7049 - val_categorical_accuracy: 0.9032
# Epoch 152/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1238 - categorical_accuracy: 0.9800
# Epoch 152: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1238 - categorical_accuracy: 0.9800 - val_loss: 0.8848 - val_categorical_accuracy: 0.9032
# Epoch 153/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1442 - categorical_accuracy: 0.9777
# Epoch 153: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1458 - categorical_accuracy: 0.9760 - val_loss: 0.7055 - val_categorical_accuracy: 0.9194
# Epoch 154/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0940 - categorical_accuracy: 0.9911
# Epoch 154: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0922 - categorical_accuracy: 0.9920 - val_loss: 0.6221 - val_categorical_accuracy: 0.9032
# Epoch 155/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0944 - categorical_accuracy: 0.9860
# Epoch 155: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0944 - categorical_accuracy: 0.9860 - val_loss: 0.7573 - val_categorical_accuracy: 0.9032
# Epoch 156/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1018 - categorical_accuracy: 0.9840
# Epoch 156: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1018 - categorical_accuracy: 0.9840 - val_loss: 0.8590 - val_categorical_accuracy: 0.9355
# Epoch 157/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0986 - categorical_accuracy: 0.9880
# Epoch 157: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0986 - categorical_accuracy: 0.9880 - val_loss: 0.7801 - val_categorical_accuracy: 0.9194
# Epoch 158/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0853 - categorical_accuracy: 0.9880
# Epoch 158: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0853 - categorical_accuracy: 0.9880 - val_loss: 0.7128 - val_categorical_accuracy: 0.9194
# Epoch 159/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0719 - categorical_accuracy: 0.9980
# Epoch 159: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0719 - categorical_accuracy: 0.9980 - val_loss: 0.7098 - val_categorical_accuracy: 0.9355
# Epoch 160/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0792 - categorical_accuracy: 0.9911
# Epoch 160: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0777 - categorical_accuracy: 0.9920 - val_loss: 0.8603 - val_categorical_accuracy: 0.9355
# Epoch 161/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0865 - categorical_accuracy: 0.9880
# Epoch 161: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0865 - categorical_accuracy: 0.9880 - val_loss: 1.0217 - val_categorical_accuracy: 0.9032
# Epoch 162/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0683 - categorical_accuracy: 0.9978
# Epoch 162: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0683 - categorical_accuracy: 0.9980 - val_loss: 1.0353 - val_categorical_accuracy: 0.8871
# Epoch 163/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0716 - categorical_accuracy: 0.9978
# Epoch 163: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0708 - categorical_accuracy: 0.9980 - val_loss: 1.0843 - val_categorical_accuracy: 0.8710
# Epoch 164/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0690 - categorical_accuracy: 0.9978
# Epoch 164: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0685 - categorical_accuracy: 0.9980 - val_loss: 1.0566 - val_categorical_accuracy: 0.9032
# Epoch 165/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0677 - categorical_accuracy: 0.9978
# Epoch 165: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0673 - categorical_accuracy: 0.9980 - val_loss: 0.9342 - val_categorical_accuracy: 0.8871
# Epoch 166/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0655 - categorical_accuracy: 0.9980
# Epoch 166: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0655 - categorical_accuracy: 0.9980 - val_loss: 0.8321 - val_categorical_accuracy: 0.9032
# Epoch 167/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0639 - categorical_accuracy: 0.9978
# Epoch 167: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0636 - categorical_accuracy: 0.9980 - val_loss: 0.7233 - val_categorical_accuracy: 0.9032
# Epoch 168/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0635 - categorical_accuracy: 1.0000
# Epoch 168: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0632 - categorical_accuracy: 1.0000 - val_loss: 0.5464 - val_categorical_accuracy: 0.9032
# Epoch 169/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0637 - categorical_accuracy: 0.9978
# Epoch 169: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0637 - categorical_accuracy: 0.9980 - val_loss: 0.5672 - val_categorical_accuracy: 0.9032
# Epoch 170/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0626 - categorical_accuracy: 1.0000
# Epoch 170: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0626 - categorical_accuracy: 1.0000 - val_loss: 0.8843 - val_categorical_accuracy: 0.9032
# Epoch 171/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0616 - categorical_accuracy: 1.0000
# Epoch 171: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0616 - categorical_accuracy: 1.0000 - val_loss: 1.1072 - val_categorical_accuracy: 0.9032
# Epoch 172/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0863 - categorical_accuracy: 0.9888
# Epoch 172: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0842 - categorical_accuracy: 0.9900 - val_loss: 0.7634 - val_categorical_accuracy: 0.9194
# Epoch 173/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0669 - categorical_accuracy: 0.9978
# Epoch 173: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0661 - categorical_accuracy: 0.9980 - val_loss: 0.6849 - val_categorical_accuracy: 0.9194
# Epoch 174/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0655 - categorical_accuracy: 0.9955
# Epoch 174: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0654 - categorical_accuracy: 0.9960 - val_loss: 0.5882 - val_categorical_accuracy: 0.9032
# Epoch 175/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0654 - categorical_accuracy: 0.9955
# Epoch 175: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0646 - categorical_accuracy: 0.9960 - val_loss: 0.5360 - val_categorical_accuracy: 0.9032
# Epoch 176/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0722 - categorical_accuracy: 0.9933
# Epoch 176: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0707 - categorical_accuracy: 0.9940 - val_loss: 0.5084 - val_categorical_accuracy: 0.9194
# Epoch 177/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0631 - categorical_accuracy: 0.9978
# Epoch 177: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0630 - categorical_accuracy: 0.9980 - val_loss: 0.6139 - val_categorical_accuracy: 0.9194
# Epoch 178/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0608 - categorical_accuracy: 1.0000
# Epoch 178: val_categorical_accuracy did not improve from 0.96774
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0608 - categorical_accuracy: 1.0000 - val_loss: 0.7090 - val_categorical_accuracy: 0.9194
# Epoch 179/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0612 - categorical_accuracy: 1.0000
# Epoch 179: val_categorical_accuracy did not improve from 0.96774
# Restoring model weights from the end of the best epoch: 79.
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0608 - categorical_accuracy: 1.0000 - val_loss: 0.9738 - val_categorical_accuracy: 0.9194
# Epoch 179: early stopping
# Training completed in time:  0:00:31.958080

# %%
train_acc = model.evaluate(X_train,y_train)
val_acc = model.evaluate(X_val,y_val)
test_acc = model.evaluate(X_test,y_test)
# Out:
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0697 - categorical_accuracy: 1.0000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2586 - categorical_accuracy: 0.9677
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6478 - categorical_accuracy: 0.9375

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

y_predicted = model.predict(X_test)

mat = confusion_matrix(y_test.argmax(axis=1), y_predicted.argmax(axis=1))

#class_labels = ["Healthy",'Bengin ', 'Malignant']
#class_labels = ["Healthy",'Bengin / Malignant']
class_labels = ['Bengin' , 'Malignant']


sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
             xticklabels=class_labels,
             yticklabels=class_labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')

plt.savefig(stage+'heatmap.png')
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
np.save(stage+'X_train.npy', X_train)
np.save(stage+'y_train.npy', y_train)

np.save(stage+'X_test.npy', X_test)
np.save(stage+'y_test.npy', y_test)

np.save(stage+'X_val.npy', X_val)
np.save(stage+'y_val.npy', y_val)

# %%
import matplotlib.pyplot as plt

acc = hist.history['categorical_accuracy']
val_acc = hist.history['val_categorical_accuracy']
epochs = range(1, len(acc) + 1)
 
plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.plot()

plt.savefig(stage+'graph.png')

best_score = max(hist.history['val_categorical_accuracy'])

print(best_score)
# Out:
# 0.9677419066429138
